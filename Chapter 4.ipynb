# %% [markdown]
# ## <span style="font-family: Arial; font-weight:bold;font-size:1.9em;color:#0e92ea">Chapter 4: Data Distributions</span><br><br>

# %% [markdown]
# ###  <span style="font-family: Arial; font-weight:bold;font-size:1.9em;color:#0e92ea">Definitions</span><br>

# %% [markdown]
# ######  <span style="font-family: Arial; font-weight:bold;font-size:1.4em;color:#0e92ea">Binomial Distribution</span>
#
# [A binomial distribution can be thought of as simply the probability of a SUCCESS or FAILURE outcome in an experiment or survey that is repeated multiple times. The binomial is a type of distribution that has two possible outcomes (the prefix “bi” means two, or twice). For example, a coin toss has only two possible outcomes: heads or tails and taking a test could have two possible outcomes: pass or fail.](https://www.statisticshowto.com/probability-and-statistics/binomial-theorem/binomial-distribution-formula/)
#
# ######  <span style="font-family: Arial; font-weight:bold;font-size:1.4em;color:#0e92ea">Normal Curve</span>
#
# - The normal distribution is a continuous probability distribution that is symmetrical on both sides of the mean, so the right side of the center is a mirror image of the left side.<br>
#
# - A normal distribution is a density curve and has a total area of 1.
#
# - A normal curve is determined by the mean and the standard deviation.
#
# ![image-2.png](attachment:image-2.png)
#
# ######  <span style="font-family: Arial; font-weight:bold;font-size:1.4em;color:#0e92ea">Emperical Rule for Normal Curve</span>
#
# - 2/3 of the data falls within 1 standard deviation of the mean.<br>
#
# - 95% of the data falls within 2 standard deviation of the mean.<br>
#
# - 99.7% (allmost all of the data) falls within 3 standard deviation of the mean.<br>

# %% [markdown]
# ######  <span style="font-family: Arial; font-weight:bold;font-size:1.4em;color:#0e92ea">Standadizing Data</span>
#
#
# ######  <span style="font-family: Arial; font-weight:bold;font-size:1.1em;color:#0e92ea">Scaling</span>
#
# - Multiplying or dividing by a constant / a combination of both.
#
# $
# x^` = \frac {X_i}{N}
# $
#
# OR
#
# $
# x^` = X_i \times N
# $
#
# ######  <span style="font-family: Arial; font-weight:bold;font-size:1.1em;color:#0e92ea">Z score</span>
#
# $
# x^` = \frac {X_i - Mean(X)}{\sigma}
# $
#
# - This is a linear transformation
# - Z score makes the mean 0 and standard deviation 1
# - Z score tells us how many standard deviations from the mean a point is.
# - Helps us calculate the area under the distribution curve
#
#
# ######  <span style="font-family: Arial; font-weight:bold;font-size:1.1em;color:#0e92ea">Normalization</span>
#
# - Squeezes the data between 0 and 1
#
# $
# x^` = \frac {X_i - X_min}{X_max - X_min}
# $
#
# ######  <span style="font-family: Arial; font-weight:bold;font-size:1.1em;color:#0e92ea">The Binomial Coefficient</span>
#
# ![image.png](attachment:image.png)
#
# - n = The number of experiments
# - k = the number of ways to arrange k successes in N experiments
#
# ######  <span style="font-family: Arial; font-weight:bold;font-size:1.1em;color:#0e92ea">The Binomial Formula</span>
#
# ![image-2.png](attachment:image-2.png)
#
# -
